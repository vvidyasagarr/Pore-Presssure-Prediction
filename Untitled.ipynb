# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
well1 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 1.csv')
well2 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 2.csv')
well3 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 3.csv')
well4 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 4.csv')
well5 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 5.csv')
well6 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 6.csv')
well7 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 7.csv')
well8 = pd.read_csv('/Users/vidyasagar/Documents/ml_projects/Pore Pressure/well 8.csv')

# %%
df = pd.concat([well1,well2,well3,well4,well5,well6,well7,well8])

# %%
df.shape
# Out:
# (11494, 10)

# %%
df
# Out:
#          DEPTH        GR    RHOB      Vp       Vsh  Caliper  Porosity  \
# 0      22.0024   57.3820  1.4506  1.4614  0.033808  11.4844   66.1596
# 1      22.1548   58.0070  1.4506  1.4594  0.044766  11.4844   66.1591
# 2      22.3072   59.1046  1.4506  1.4577  0.064012  11.4844   66.1585
# 3      22.4596   59.2124  1.4506  1.4567  0.065902  11.4844   66.1581
# 4      22.6120   59.8294  1.4506  1.4564  0.076721  11.4844   66.1575
# ...        ...       ...     ...     ...       ...      ...       ...
# 1038  181.3026  105.3357  1.8353  1.4914  0.898063   9.9461   51.5604
# 1039  181.4550  103.8500  1.8245  1.4815  0.876908   9.9117   54.9033
# 1040  181.6074  103.2400  1.8128  1.4755  0.868221   9.8249   52.2509
# 1041  181.7598  102.9838  1.7950  1.4691  0.864573   9.8545   53.2176
# 1042  181.9122  102.4681  1.7789  1.4668  0.857230   9.9515   51.5455
#
#       Resistivity        Stress      PP
# 0          0.7881  3.127835e+05  1609.0
# 1          0.7751  3.149500e+05  1609.0
# 2          0.7798  3.171165e+05  1609.0
# 3          0.7711  3.192830e+05  1609.0
# 4          0.7446  3.214495e+05  1609.0
# ...           ...           ...     ...
# 1038       1.1152  3.260898e+06  1805.0
# 1039       1.1240  3.244434e+06  1805.0
# 1040       1.1346  3.226335e+06  1803.0
# 1041       1.1472  3.197337e+06  1808.0
# 1042       1.1467  3.171315e+06  1808.0
#
# [11494 rows x 10 columns]

# %%
df.head()
# Out:
#      DEPTH       GR    RHOB      Vp       Vsh  Caliper  Porosity  Resistivity  \
# 0  22.0024  57.3820  1.4506  1.4614  0.033808  11.4844   66.1596       0.7881
# 1  22.1548  58.0070  1.4506  1.4594  0.044766  11.4844   66.1591       0.7751
# 2  22.3072  59.1046  1.4506  1.4577  0.064012  11.4844   66.1585       0.7798
# 3  22.4596  59.2124  1.4506  1.4567  0.065902  11.4844   66.1581       0.7711
# 4  22.6120  59.8294  1.4506  1.4564  0.076721  11.4844   66.1575       0.7446
#
#         Stress      PP
# 0  312783.4781  1609.0
# 1  314949.9782  1609.0
# 2  317116.4783  1609.0
# 3  319282.9784  1609.0
# 4  321449.4786  1609.0

# %%
df.isnull().sum()
# Out:
# DEPTH          0
# GR             0
# RHOB           0
# Vp             0
# Vsh            0
# Caliper        0
# Porosity       0
# Resistivity    0
# Stress         0
# PP             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['DEPTH', 'GR', 'RHOB', 'Vp', 'Vsh', 'Caliper', 'Porosity',
#        'Resistivity', 'Stress', 'PP'],
#       dtype='object')

# %%
cols = ['DEPTH', 'GR', 'RHOB', 'Vp', 'Vsh', 'Caliper', 'Porosity',
       'Resistivity', 'Stress', 'PP']

# %%
for col in cols:
    plt.figure()
    sns.boxplot(df[col])
# Out:
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(13,10))
plt.subplot(3,2,1)
sns.boxplot(df['GR'])
#plt.title('Before Outlier Removal', size=15)

plt.subplot(3,2,2)
sns.boxplot(df['GR'])
#plt.title('After Outlier Removal with Standard Deviation Filter', size=15)

plt.subplot(3,2,3)
sns.boxplot(df['RHOB'])
#plt.title('After Outlier Removal with Isolation Forest', size=15)

plt.subplot(3,2,4)
sns.boxplot(df['Vp'])
#plt.title('After Outlier Removal with Min. Covariance', size=15)

plt.subplot(3,2,5)
sns.boxplot(df['Vsh'])
#plt.title('After Outlier Removal with Local Outlier Factor', size=15)

plt.subplot(3,2,6)
sns.boxplot(df['Caliper'])
#plt.title('After Outlier Removal with One-class SVM', size=15)

plt.tight_layout(1.7)
plt.show()
# Out:
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 26>()
#      23 sns.boxplot(df['Caliper'])
#      24 #plt.title('After Outlier Removal with One-class SVM', size=15)
# ---> 26 plt.tight_layout(1.7)
#      27 plt.show()
#
# TypeError: tight_layout() takes 0 positional arguments but 1 was given

# %%
# GR

df['GR'][df['GR']<70]= np.nan
# RHOB
df['RHOB'][df['RHOB']<1.5] = np.nan
# Vp
df['Vp'][df['Vp']>1.70] = np.nan
# Vsh
df['Vsh'][df['Vsh']<0.37] = np.nan
# Caliper
df['Caliper'][df['Caliper']>11]= np.nan
# Porosity
df['Porosity'][df['Porosity']>75]= np.nan
# Resistivity
df['Resistivity'][df['Resistivity']>1.5]= np.nan

# %%
df= df.dropna()

# %%
for col in cols :
    plt.figure()
    sns.boxplot(df[col])
# Out:
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/vidyasagar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print('Train size: ',df.shape)
# Out:
# Train size:  (10408, 10)

# %%
sns.displot(df[['GR', 'RHOB', 'Vp', 'Vsh', 'Caliper', 'Porosity',
       'Resistivity']])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale= MinMaxScaler()

# %%
cols= ['GR', 'RHOB', 'Vp', 'Vsh', 'Caliper', 'Porosity',
       'Resistivity','Stress']

# %%
scaled= scale.fit_transform(df[['GR', 'RHOB', 'Vp', 'Vsh', 'Caliper', 'Porosity',
       'Resistivity','Stress']])

# %%
scaled_df= pd.DataFrame(scaled,columns= cols)

# %%
df= df.reset_index()

# %%
scaled_df
# Out:
#              GR      RHOB        Vp       Vsh   Caliper  Porosity  \
# 0      0.095351  0.087316  0.999789  0.002970  0.937192  0.726727
# 1      0.277994  0.098007  0.999792  0.187648  0.930059  0.804398
# 2      0.146424  0.144986  0.999797  0.230534  0.858793  0.764288
# 3      0.047101  0.162644  0.999799  0.173578  0.860497  0.803269
# 4      0.152046  0.136724  0.999803  0.194618  0.917498  0.804055
# ...         ...       ...       ...       ...       ...       ...
# 10403  0.785251  0.543010  0.999793  0.792334  0.335059  0.307047
# 10404  0.752223  0.525514  0.999783  0.760394  0.313344  0.405877
# 10405  0.738662  0.506561  0.999777  0.747281  0.258553  0.327461
# 10406  0.732966  0.477726  0.999770  0.741773  0.277238  0.356041
# 10407  0.721502  0.451644  0.999768  0.730686  0.338467  0.306606
#
#        Resistivity    Stress
# 0         0.314069  0.017649
# 1         0.334395  0.018335
# 2         0.363338  0.023780
# 3         0.391064  0.024718
# 4         0.391907  0.025682
# ...            ...       ...
# 10403     0.641158  0.438688
# 10404     0.649401  0.436171
# 10405     0.659329  0.433404
# 10406     0.671132  0.428971
# 10407     0.670663  0.424993
#
# [10408 rows x 8 columns]

# %%
merge= [df['DEPTH'],df['PP'],scaled_df]
pd.concat(merge,axis=1)
# Out:
#           DEPTH      PP        GR      RHOB        Vp       Vsh   Caliper  \
# 0       33.2800  1617.0  0.095351  0.087316  0.999789  0.002970  0.937192
# 1       33.4324  1620.0  0.277994  0.098007  0.999792  0.187648  0.930059
# 2       35.1088  1621.0  0.146424  0.144986  0.999797  0.230534  0.858793
# 3       35.2612  1620.0  0.047101  0.162644  0.999799  0.173578  0.860497
# 4       36.0232  1622.0  0.152046  0.136724  0.999803  0.194618  0.917498
# ...         ...     ...       ...       ...       ...       ...       ...
# 10403  181.3026  1805.0  0.785251  0.543010  0.999793  0.792334  0.335059
# 10404  181.4550  1805.0  0.752223  0.525514  0.999783  0.760394  0.313344
# 10405  181.6074  1803.0  0.738662  0.506561  0.999777  0.747281  0.258553
# 10406  181.7598  1808.0  0.732966  0.477726  0.999770  0.741773  0.277238
# 10407  181.9122  1808.0  0.721502  0.451644  0.999768  0.730686  0.338467
#
#        Porosity  Resistivity    Stress
# 0      0.726727     0.314069  0.017649
# 1      0.804398     0.334395  0.018335
# 2      0.764288     0.363338  0.023780
# 3      0.803269     0.391064  0.024718
# 4      0.804055     0.391907  0.025682
# ...         ...          ...       ...
# 10403  0.307047     0.641158  0.438688
# 10404  0.405877     0.649401  0.436171
# 10405  0.327461     0.659329  0.433404
# 10406  0.356041     0.671132  0.428971
# 10407  0.306606     0.670663  0.424993
#
# [10408 rows x 10 columns]

# %%
df_scaled= pd.concat(merge,axis=1)

# %%
sns.displot(df_scaled[['GR', 'RHOB', 'Vp', 'Vsh', 'Caliper', 'Porosity',
       'Resistivity','Stress']])

# %%
sns.set_theme(style="white")
plt.figure(dpi = (100))
sns.jointplot(x = df['Porosity'], y = df['PP'], kind='reg', line_kws={"color": "red"})

# %%
sns.set_theme(style="white")
plt.figure(dpi = (100))
sns.jointplot(x = df['RHOB'], y = df['PP'], kind='reg', line_kws={"color": "red"})

# %%
df= df_scaled.drop(['Vp'],axis=1)
df
# Out:
#           DEPTH      PP        GR      RHOB       Vsh   Caliper  Porosity  \
# 0       33.2800  1617.0  0.095351  0.087316  0.002970  0.937192  0.726727
# 1       33.4324  1620.0  0.277994  0.098007  0.187648  0.930059  0.804398
# 2       35.1088  1621.0  0.146424  0.144986  0.230534  0.858793  0.764288
# 3       35.2612  1620.0  0.047101  0.162644  0.173578  0.860497  0.803269
# 4       36.0232  1622.0  0.152046  0.136724  0.194618  0.917498  0.804055
# ...         ...     ...       ...       ...       ...       ...       ...
# 10403  181.3026  1805.0  0.785251  0.543010  0.792334  0.335059  0.307047
# 10404  181.4550  1805.0  0.752223  0.525514  0.760394  0.313344  0.405877
# 10405  181.6074  1803.0  0.738662  0.506561  0.747281  0.258553  0.327461
# 10406  181.7598  1808.0  0.732966  0.477726  0.741773  0.277238  0.356041
# 10407  181.9122  1808.0  0.721502  0.451644  0.730686  0.338467  0.306606
#
#        Resistivity    Stress
# 0         0.314069  0.017649
# 1         0.334395  0.018335
# 2         0.363338  0.023780
# 3         0.391064  0.024718
# 4         0.391907  0.025682
# ...            ...       ...
# 10403     0.641158  0.438688
# 10404     0.649401  0.436171
# 10405     0.659329  0.433404
# 10406     0.671132  0.428971
# 10407     0.670663  0.424993
#
# [10408 rows x 9 columns]

# %%
df.corr()
# Out:
#                 DEPTH        PP        GR      RHOB       Vsh   Caliper  \
# DEPTH        1.000000  0.709591  0.228171  0.596943  0.183359 -0.470626
# PP           0.709591  1.000000  0.297317  0.618000  0.327807 -0.467341
# GR           0.228171  0.297317  1.000000  0.448181  0.928665 -0.216557
# RHOB         0.596943  0.618000  0.448181  1.000000  0.447860 -0.482734
# Vsh          0.183359  0.327807  0.928665  0.447860  1.000000 -0.237762
# Caliper     -0.470626 -0.467341 -0.216557 -0.482734 -0.237762  1.000000
# Porosity    -0.529550 -0.562232 -0.427141 -0.870870 -0.435956  0.375908
# Resistivity  0.512857  0.654209  0.200921  0.442243  0.237863 -0.416026
# Stress       0.995396  0.725342  0.249181  0.653090  0.206708 -0.470615
#
#              Porosity  Resistivity    Stress
# DEPTH       -0.529550     0.512857  0.995396
# PP          -0.562232     0.654209  0.725342
# GR          -0.427141     0.200921  0.249181
# RHOB        -0.870870     0.442243  0.653090
# Vsh         -0.435956     0.237863  0.206708
# Caliper      0.375908    -0.416026 -0.470615
# Porosity     1.000000    -0.407968 -0.578736
# Resistivity -0.407968     1.000000  0.522337
# Stress      -0.578736     0.522337  1.000000

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(df.corr(), annot=True, cmap='Dark2_r', linewidths = 2)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop(['PP','DEPTH'],axis=1) ##independent var
y= df['PP'] ## dependent var

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
pred = model.predict(x_test)
 
train_score = model.score(x_train, y_train)
print(f'Train score of trained model: {train_score*100}')

test_score = model.score(x_test, y_test)
print(f'Test score of trained model: {test_score*100}')
# Out:
# Train score of trained model: 66.45814272114728
# Test score of trained model: 66.76129338187422

# %%
sns.set_theme(style="white")
sns.jointplot(x=y_test, y=pred, kind='reg', line_kws={"color": "red"})

## Plot for observing the predicted and actual values

# %%
import sklearn.metrics as metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from math import sqrt

k = x_test.shape[1]
n = len(x_test)

MSE = mean_squared_error(y_test, pred)
RMSE = np.sqrt(metrics.mean_squared_error(y_test, pred))
MAE = mean_absolute_error(y_test, pred)
MAPE = np.mean(np.abs( (y_test-pred) / y_test))*100
r2_linreg = r2_score(y_test, pred)
adj_r2 = 1-(1-r2_linreg) * (n-1)/(n-k-1)

results = [MSE, RMSE, MAE, MAPE, r2_linreg, adj_r2]
metrics = ['MSE', 'RMSE', 'MAE', 'MAPE', 'r2', 'adj_r2']

table_results = pd.DataFrame({'Metric': metrics, 'Score': results})
table_results
# Out:
#    Metric         Score
# 0     MSE  14416.857029
# 1    RMSE    120.070217
# 2     MAE     93.101311
# 3    MAPE      5.086101
# 4      r2      0.667613
# 5  adj_r2      0.666491

# %%
from sklearn.ensemble import RandomForestRegressor

reg=RandomForestRegressor()

reg.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
pred=reg.predict(x_test)

# %%
rf_acc=r2_score(y_test, pred)
print("R^2",rf_acc)
print("Adusted R^2", 1-(1-r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print("MAE", mean_absolute_error(y_test, pred))
print("MSE", mean_squared_error(y_test, pred))
print("RMSE",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R^2 0.9502465107452289
# Adusted R^2 0.9500785867217075
# MAE 25.596046734870317
# MSE 2157.992937333435
# RMSE 46.454202579889746

# %%
# visualize the difference between the actual and predicted price 
plt.scatter(y_test, pred)
plt.xlabel("Pore Pressure")
plt.ylabel("Predicted Pore Pressure")
plt.title("Predicted Vs Actual for Random Forest")
plt.show()

# %%
from sklearn import svm

regg=svm.SVR()
regg.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred=regg.predict(x_test)

# %%
regg_acc=r2_score(y_test, pred)
print("R^2",regg_acc)
print("Adusted R^2", 1-(1-r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print("MAE", mean_absolute_error(y_test, pred))
print("MSE", mean_squared_error(y_test, pred))
print("RMSE",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R^2 0.6612173963568495
# Adusted R^2 0.6600739642326923
# MAE 92.75511959855794
# MSE 14694.255154843095
# RMSE 121.21986287256348

# %%
# visualize the difference between the actual and predicted price 
plt.scatter(y_test, pred)
plt.xlabel("Pore Pressure")
plt.ylabel("Predicted Pore Pressure")
plt.title("Predicted Vs Actual for SVM ")
plt.show()

# %%
from tensorflow import keras

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

seed = 7
np.random.seed(seed)

# Model
model = Sequential()
model.add(Dense(200, input_dim=7, kernel_initializer='normal', activation='relu'))
model.add(Dense(100, kernel_initializer='normal', activation='relu'))
model.add(Dense(50, kernel_initializer='normal', activation='relu'))
model.add(Dense(25, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
# Compile model
model.compile(loss='mean_squared_error')

feature_cols = x_train
labels = y_train.values

model.fit(np.array(feature_cols), np.array(labels), epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 2022-12-16 23:11:07.581255: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 833/833 [==============================] - 2s 2ms/step - loss: 399967.1562
# Epoch 2/100
# 833/833 [==============================] - 1s 2ms/step - loss: 19180.5703
# Epoch 3/100
# 833/833 [==============================] - 1s 2ms/step - loss: 17999.3867
# Epoch 4/100
# 833/833 [==============================] - 2s 2ms/step - loss: 17327.7539
# Epoch 5/100
# 833/833 [==============================] - 2s 2ms/step - loss: 16609.5508
# Epoch 6/100
# 833/833 [==============================] - 1s 2ms/step - loss: 16076.0205
# Epoch 7/100
# 833/833 [==============================] - 1s 2ms/step - loss: 15405.5820
# Epoch 8/100
# 833/833 [==============================] - 1s 2ms/step - loss: 14911.4521
# Epoch 9/100
# 833/833 [==============================] - 2s 2ms/step - loss: 14651.1182
# Epoch 10/100
# 833/833 [==============================] - 2s 2ms/step - loss: 14277.0098
# Epoch 11/100
# 833/833 [==============================] - 1s 2ms/step - loss: 13921.8496
# Epoch 12/100
# 833/833 [==============================] - 2s 2ms/step - loss: 13613.5059
# Epoch 13/100
# 833/833 [==============================] - 2s 2ms/step - loss: 13430.0488
# Epoch 14/100
# 833/833 [==============================] - 1s 2ms/step - loss: 13229.0557
# Epoch 15/100
# 833/833 [==============================] - 1s 2ms/step - loss: 13165.2646
# Epoch 16/100
# 833/833 [==============================] - 1s 2ms/step - loss: 12923.6055
# Epoch 17/100
# 833/833 [==============================] - 2s 2ms/step - loss: 13002.1367
# Epoch 18/100
# 833/833 [==============================] - 2s 2ms/step - loss: 12716.1562
# Epoch 19/100
# 833/833 [==============================] - 1s 2ms/step - loss: 12389.9443
# Epoch 20/100
# 833/833 [==============================] - 1s 2ms/step - loss: 12369.1416
# Epoch 21/100
# 833/833 [==============================] - 2s 2ms/step - loss: 12347.7295
# Epoch 22/100
# 833/833 [==============================] - 1s 2ms/step - loss: 12374.3799
# Epoch 23/100
# 833/833 [==============================] - 2s 2ms/step - loss: 12165.6680
# Epoch 24/100
# 833/833 [==============================] - 2s 2ms/step - loss: 12093.9697
# Epoch 25/100
# 833/833 [==============================] - 1s 2ms/step - loss: 12079.7529
# Epoch 26/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11946.2764
# Epoch 27/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11856.8994
# Epoch 28/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11887.9121
# Epoch 29/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11762.6709
# Epoch 30/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11705.6748
# Epoch 31/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11661.3174
# Epoch 32/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11629.1240
# Epoch 33/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11488.1445
# Epoch 34/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11532.8262
# Epoch 35/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11516.6934
# Epoch 36/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11372.3877
# Epoch 37/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11484.3975
# Epoch 38/100
# 833/833 [==============================] - 3s 3ms/step - loss: 11397.9160
# Epoch 39/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11402.0000
# Epoch 40/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11426.0303
# Epoch 41/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11407.4795
# Epoch 42/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11306.2002
# Epoch 43/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11222.1416
# Epoch 44/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11186.0557
# Epoch 45/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11118.1406
# Epoch 46/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11171.3359
# Epoch 47/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11187.0615
# Epoch 48/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11151.4482
# Epoch 49/100
# 833/833 [==============================] - 2s 2ms/step - loss: 11032.4814
# Epoch 50/100
# 833/833 [==============================] - 1s 2ms/step - loss: 11020.0508
# Epoch 51/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10951.7168
# Epoch 52/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10933.5342
# Epoch 53/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10940.2305
# Epoch 54/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10836.8438
# Epoch 55/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10736.0059
# Epoch 56/100
# 833/833 [==============================] - 2s 2ms/step - loss: 10663.4189
# Epoch 57/100
# 833/833 [==============================] - 2s 2ms/step - loss: 10746.1377
# Epoch 58/100
# 833/833 [==============================] - 2s 2ms/step - loss: 10713.7676
# Epoch 59/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10610.2139
# Epoch 60/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10528.5977
# Epoch 61/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10379.0820
# Epoch 62/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10380.5303
# Epoch 63/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10311.6982
# Epoch 64/100
# 833/833 [==============================] - 1s 2ms/step - loss: 10179.4668
# Epoch 65/100
# 833/833 [==============================] - 2s 2ms/step - loss: 10172.7422
# Epoch 66/100
# 833/833 [==============================] - 2s 2ms/step - loss: 10147.9111
# Epoch 67/100
# 833/833 [==============================] - 2s 2ms/step - loss: 10034.4736
# Epoch 68/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9956.6211
# Epoch 69/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9916.0723
# Epoch 70/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9899.6904
# Epoch 71/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9710.8604
# Epoch 72/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9863.2773
# Epoch 73/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9712.9004
# Epoch 74/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9630.4199
# Epoch 75/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9547.8613
# Epoch 76/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9543.6602
# Epoch 77/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9440.6377
# Epoch 78/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9386.5156
# Epoch 79/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9461.9619
# Epoch 80/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9335.0059
# Epoch 81/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9323.6504
# Epoch 82/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9085.9473
# Epoch 83/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9175.2305
# Epoch 84/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9173.6748
# Epoch 85/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9107.0947
# Epoch 86/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9148.3584
# Epoch 87/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9073.1885
# Epoch 88/100
# 833/833 [==============================] - 2s 2ms/step - loss: 9064.6484
# Epoch 89/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8968.7227
# Epoch 90/100
# 833/833 [==============================] - 2s 2ms/step - loss: 8988.8867
# Epoch 91/100
# 833/833 [==============================] - 1s 2ms/step - loss: 9055.9404
# Epoch 92/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8958.5371
# Epoch 93/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8861.0059
# Epoch 94/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8795.6025
# Epoch 95/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8878.6865
# Epoch 96/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8797.4570
# Epoch 97/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8730.6406
# Epoch 98/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8794.7129
# Epoch 99/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8789.5615
# Epoch 100/100
# 833/833 [==============================] - 1s 2ms/step - loss: 8778.3242

# %%
pred= model.predict(x_test)
# Out:
# 66/66 [==============================] - 0s 2ms/step

# %%
ann_acc=r2_score(y_test, pred)
print("R^2",ann_acc)
print("Adusted R^2", 1-(1-r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print("MAE", mean_absolute_error(y_test, pred))
print("MSE", mean_squared_error(y_test, pred))
print("RMSE",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R^2 0.8344334610417755
# Adusted R^2 0.8338746540153977
# MAE 65.5031073844448
# MSE 7181.2334588438325
# RMSE 84.74215868647572

# %%
# visualize the difference between the actual and predicted price 
plt.scatter(y_test, pred)
plt.xlabel("Pore Pressure")
plt.ylabel("Predicted Pore Pressure")
plt.title("Predicted Vs Actual for ANN")
plt.show()
